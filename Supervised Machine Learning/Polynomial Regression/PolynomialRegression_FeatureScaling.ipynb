# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
# Generate synthetic data
np.random.seed(0)
X = np.random.rand(10, 1) * 5
y = 2 * X + 1.5 * X**2 + np.random.rand(10, 1)
# Out:
# [[0.5488135 ]
#  [0.71518937]
#  [0.60276338]
#  [0.54488318]
#  [0.4236548 ]
#  [0.64589411]
#  [0.43758721]
#  [0.891773  ]
#  [0.96366276]
#  [0.38344152]]

# %%
# Apply feature scaling (Standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Polynomial feature transformation
degree = 2  # Degree of the polynomial features
poly = PolynomialFeatures(degree=degree)
X_poly = poly.fit_transform(X_scaled)

# %%
# Create and train a polynomial regression model
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Visualize the results
X_range = np.linspace(0, 5, 100)[:, np.newaxis]
X_range_scaled = scaler.transform(X_range)
X_range_poly = poly.transform(X_range_scaled)
y_range_pred = poly_reg.predict(X_range_poly)

# %%
plt.scatter(X, y, label='Data')
plt.plot(X_range, y_range_pred, color='r', label=f'Polynomial Regression (Degree {degree})')
plt.xlabel('X')
plt.ylabel('y')
plt.title(f'Synthetic Data - Polynomial Regression (Degree {degree})')
plt.legend()
plt.grid(True)
plt.show()
