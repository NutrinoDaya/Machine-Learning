# %%
import numpy as np 
import pandas as pd

# %%
books = pd.read_csv("data/Preprocessed_data.csv",sep=",",encoding='utf-8')
users = pd.read_csv('data/BX-Users.csv',sep=';',encoding='latin-1')
ratings = pd.read_csv('data/BX-Book-Ratings.csv',sep=';',encoding='latin-1')
books.rename(columns={"isbn":"ISBN"},inplace=True)
# books.rename(columns={"rating":"Book-Rating"},inplace=True)

# %%
books['img_l'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (1031175, 18)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# user_id                    0
# location                   0
# age                        0
# ISBN                       0
# rating                     0
# book_title                 0
# book_author                1
# year_of_publication        0
# publisher                  0
# img_s                      0
# img_m                      0
# img_l                      0
# Summary                    0
# Language                   0
# Category                   0
# city                   14103
# state                  22798
# country                35374
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %% [markdown]
# ## Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books, on="ISBN")

# %%
ratings_with_name.head(5)
# Out:
#    User-ID        ISBN  Book-Rating  user_id  \
# 0   276725  034545104X            0     2313
# 1   276725  034545104X            0     6543
# 2   276725  034545104X            0     8680
# 3   276725  034545104X            0    10314
# 4   276725  034545104X            0    23768
#
#                             location      age  rating            book_title  \
# 0              cincinnati, ohio, usa  23.0000       5  Flesh Tones: A Novel
# 1           strafford, missouri, usa  34.0000       0  Flesh Tones: A Novel
# 2  st. charles county, missouri, usa  34.7439       5  Flesh Tones: A Novel
# 3             beaverton, oregon, usa  34.7439       9  Flesh Tones: A Novel
# 4           st. louis, missouri, usa  45.0000       0  Flesh Tones: A Novel
#
#   book_author  year_of_publication         publisher  \
# 0  M. J. Rose               2002.0  Ballantine Books
# 1  M. J. Rose               2002.0  Ballantine Books
# 2  M. J. Rose               2002.0  Ballantine Books
# 3  M. J. Rose               2002.0  Ballantine Books
# 4  M. J. Rose               2002.0  Ballantine Books
#
#                                                img_s  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                                img_m  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                              Summary Language     Category  \
# 0  Twenty years after having an affair with legen...       en  ['Fiction']
# 1  Twenty years after having an affair with legen...       en  ['Fiction']
# 2  Twenty years after having an affair with legen...       en  ['Fiction']
# 3  Twenty years after having an affair with legen...       en  ['Fiction']
# 4  Twenty years after having an affair with legen...       en  ['Fiction']
#
#                  city     state country
# 0          cincinnati      ohio     usa
# 1           strafford  missouri     usa
# 2  st. charles county  missouri     usa
# 3           beaverton    oregon     usa
# 4           st. louis  missouri     usa

# %%
num_rating_df = ratings_with_name.groupby('book_title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating' : 'num_ratings'},inplace=True)

# %%
num_rating_df
# Out:
#                                                book_title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...           16
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241085                                      Ã?Â?lpiraten.            4
# 241086                     Ã?Â?rger mit Produkt X. Roman.           16
# 241087                                Ã?Â?sterlich leben.            1
# 241088                              Ã?Â?stlich der Berge.            9
# 241089                                  Ã?Â?thique en toc            4
#
# [241090 rows x 2 columns]

# %%
##avg_rating_df = ratings_with_name.groupby('book_title').mean()['num_ratings'].reset_index()
ratings_with_name.head(5)
# Out:
#    User-ID        ISBN  Book-Rating  user_id  \
# 0   276725  034545104X            0     2313
# 1   276725  034545104X            0     6543
# 2   276725  034545104X            0     8680
# 3   276725  034545104X            0    10314
# 4   276725  034545104X            0    23768
#
#                             location      age  rating            book_title  \
# 0              cincinnati, ohio, usa  23.0000       5  Flesh Tones: A Novel
# 1           strafford, missouri, usa  34.0000       0  Flesh Tones: A Novel
# 2  st. charles county, missouri, usa  34.7439       5  Flesh Tones: A Novel
# 3             beaverton, oregon, usa  34.7439       9  Flesh Tones: A Novel
# 4           st. louis, missouri, usa  45.0000       0  Flesh Tones: A Novel
#
#   book_author  year_of_publication         publisher  \
# 0  M. J. Rose               2002.0  Ballantine Books
# 1  M. J. Rose               2002.0  Ballantine Books
# 2  M. J. Rose               2002.0  Ballantine Books
# 3  M. J. Rose               2002.0  Ballantine Books
# 4  M. J. Rose               2002.0  Ballantine Books
#
#                                                img_s  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                                img_m  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                              Summary Language     Category  \
# 0  Twenty years after having an affair with legen...       en  ['Fiction']
# 1  Twenty years after having an affair with legen...       en  ['Fiction']
# 2  Twenty years after having an affair with legen...       en  ['Fiction']
# 3  Twenty years after having an affair with legen...       en  ['Fiction']
# 4  Twenty years after having an affair with legen...       en  ['Fiction']
#
#                  city     state country
# 0          cincinnati      ohio     usa
# 1           strafford  missouri     usa
# 2  st. charles county  missouri     usa
# 3           beaverton    oregon     usa
# 4           st. louis  missouri     usa

# %%
# avg_rating_df = ratings_with_name.groupby('book_title').mean()['Book-Rating'].reset_index()
# avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
# avg_rating_df
avg_rating_df = ratings_with_name.groupby('book_title')['Book-Rating'].mean().reset_index()
# Rename the 'Book-Rating' column to 'avg_rating'
avg_rating_df.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)

# %%
avg_rating_df
# Out:
#                                                book_title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241085                                      Ã?Â?lpiraten.    0.000000
# 241086                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241087                                Ã?Â?sterlich leben.    7.000000
# 241088                              Ã?Â?stlich der Berge.    2.666667
# 241089                                  Ã?Â?thique en toc    4.000000
#
# [241090 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on="book_title")
popular_df
# Out:
#                                                book_title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...           16
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241085                                      Ã?Â?lpiraten.            4
# 241086                     Ã?Â?rger mit Produkt X. Roman.           16
# 241087                                Ã?Â?sterlich leben.            1
# 241088                              Ã?Â?stlich der Berge.            9
# 241089                                  Ã?Â?thique en toc            4
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# 4         0.000000
# ...            ...
# 241085    0.000000
# 241086    5.250000
# 241087    7.000000
# 241088    2.666667
# 241089    4.000000
#
# [241090 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)
popular_df
# Out:
#                                                book_title  num_ratings  \
# 70398                                                Free         2918
# 217129  There's Treasure Everywhere--A Calvin and Hobb...          289
# 58543                                           El Hobbit          538
# 80460                   Harry Potter y el cÃ¡liz de fuego          320
# 233411       Where the Sidewalk Ends : Poems and Drawings         1089
# 4348                               A Kiss for Little Bear          400
# 19438                                        Bad Business          400
# 64209                                          Falling Up         1445
# 69995   Fox in Socks (I Can Read It All by Myself Begi...          386
# 121696                             Mittsommermord. Roman.          289
# 191619       The Hobbit (Leatherette Collector's Edition)          576
# 96826                                  Johnny Got His Gun         1026
# 94583   It's A Magical World: A Calvin and Hobbes Coll...          784
# 25598   Bloom County Babylon : Five Years of Basic Nau...          324
# 112163                                   Love You Forever         1400
# 58860   El Senor De Los Anillos: LA Comunidad Del Anil...          256
# 100840                                  L'Ecume Des Jours          256
# 119662                             Metaphysique Des Tubes          324
# 143216           Preludes and Nocturnes (Sandman, Book 1)          733
# 44176                                          Dark Magic          291
# 148643                             Relato de un nÃ¡ufrago          333
# 11304                           All Over but the Shoutin'          290
# 102584                             La caverna = A caverna          289
# 178365                                    The Blue Castle          289
# 135476                              Oscar et la dame rose          361
# 191838                              The Horse and His Boy         1370
# 208586         The Stand (The Complete and Uncut Edition)         3249
# 55854                                      Dry : A Memoir          324
# 84480                          Holes (Newbery Medal Book)          576
# 65602         Feet of Clay (Discworld Novels (Paperback))          729
# 80457               Harry Potter und der Stein der Weisen          441
# 218890                               Tiger Burning Bright          250
# 155263                                      Schachnovelle          529
# 160930            Sin Noticias De Gurb (Biblioteca breve)          256
# 192675                The Indispensable Calvin And Hobbes          676
# 117872  Maus 1. Mein Vater kotzt Geschichte aus. Die G...          256
# 77814   Griffin & Sabine: An Extraordinary Correspondence         5184
# 150867                               Robert Frost's Poems          293
# 104845                                    Le Petit Prince          446
# 207654                                         The Sinner          794
# 135809                     Our Town: A Play in Three Acts          256
# 129576                        Night Of Crash-Test Dummies          625
# 74372   Gianna: Aborted... and Lived to Tell About It ...          361
# 130041                              Nine Princes In Amber          529
# 189592  The Golden Mean: In Which the Extraordinary Co...         1296
# 112925          Luck in the Shadows (Nightrunner, Vol. 1)          324
# 196059                              The Lord of the Rings          302
# 155654  Scientific Progress Goes 'Boink':  A Calvin an...         1369
# 211528      The Ultimate Hitchhiker's Guide to the Galaxy          576
# 80444      Harry Potter and the Sorcerer's Stone (Book 1)        39060
#
#         avg_rating
# 70398     7.964016
# 217129    7.882353
# 58543     7.509294
# 80460     7.250000
# 233411    7.121212
# 4348      7.100000
# 19438     7.000000
# 64209     6.916263
# 69995     6.834197
# 121696    6.823529
# 191619    6.791667
# 96826     6.744639
# 94583     6.642857
# 25598     6.611111
# 112163    6.585714
# 58860     6.562500
# 100840    6.562500
# 119662    6.500000
# 143216    6.470668
# 44176     6.453608
# 148643    6.414414
# 11304     6.413793
# 102584    6.352941
# 178365    6.352941
# 135476    6.263158
# 191838    6.211679
# 208586    6.175439
# 55854     6.166667
# 84480     6.166667
# 65602     6.148148
# 80457     6.142857
# 218890    6.140000
# 155263    6.130435
# 160930    6.125000
# 192675    6.115385
# 117872    6.062500
# 77814     6.041667
# 150867    6.027304
# 104845    6.022422
# 207654    6.017632
# 135809    6.000000
# 129576    6.000000
# 74372     6.000000
# 130041    5.956522
# 189592    5.944444
# 112925    5.944444
# 196059    5.940397
# 155654    5.918919
# 211528    5.916667
# 80444     5.900154

# %%
popular_df = popular_df.merge(books,on='book_title').drop_duplicates('book_title')[['book_title','book_author','img_m','num_ratings','avg_rating']]

# %%
popular_df['img_m'][0]
# Out:
# 'http://images.amazon.com/images/P/1844262553.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200 
padhe_likhe_users = x[x].index

# %%
print(padhe_likhe_users)
# Out:
# Index([     9,     14,     16,     17,     26,     39,     44,     51,     67,
#            75,
#        ...
#        278773, 278774, 278798, 278800, 278813, 278832, 278843, 278844, 278851,
#        278854],
#       dtype='int64', name='User-ID', length=26993)

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]
y = filtered_rating.groupby('book_title').count()['Book-Rating']>=50
famous_books = y[y].index
final_ratings = filtered_rating[filtered_rating['book_title'].isin(famous_books)]
pt = final_ratings.pivot_table(index='book_title',columns='User-ID',values='Book-Rating')
pt.fillna(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Book-Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\mo\Downloads\Machine Learning\Projects\Book Recommendation System\Book Recommendation System.ipynb Cell 25 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/mo/Downloads/Machine%20Learning/Projects/Book%20Recommendation%20System/Book%20Recommendation%20System.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> y = filtered_rating.groupby('book_title').count()['Book-Rating']>=50
#       <a href='vscode-notebook-cell:/c%3A/Users/mo/Downloads/Machine%20Learning/Projects/Book%20Recommendation%20System/Book%20Recommendation%20System.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> famous_books = y[y].index
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mo/Downloads/Machine%20Learning/Projects/Book%20Recommendation%20System/Book%20Recommendation%20System.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
#       <a href='vscode-notebook-cell:/c%3A/Users/mo/Downloads/Machine%20Learning/Projects/Book%20Recommendation%20System/Book%20Recommendation%20System.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> pt = final_ratings.pivot_table(index='book_title',columns='User-ID',values='Book-Rating')
#       <a href='vscode-notebook-cell:/c%3A/Users/mo/Downloads/Machine%20Learning/Projects/Book%20Recommendation%20System/Book%20Recommendation%20System.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> pt.fillna(0,inplace=True)
#
# File c:\Users\mo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\mo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Book-Title'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pt
