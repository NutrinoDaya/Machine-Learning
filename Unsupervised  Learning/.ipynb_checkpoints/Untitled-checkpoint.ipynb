# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Set the random seed to 0 to get the same sequence every run
np.random.seed(0)
X = 2 * np.random.rand(100, 1)  # Generate 100 random values between 0 and 2
y = 4 + 3 * X + np.random.randn(100, 1)  # Generate y with a random number

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions
X_new = np.array([[0], [2]])  # New data points to make predictions on
y_pred = model.predict(X_new)

# %%
# Plot the original data and the regression line
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X_new, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
