# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Set the random seed to 0 to get the same sequence every run
np.random.seed(0)
# Increasing  data Generalization will increase the accuracy of the predection
X = 2 * np.random.rand(50, 1)  # Generate 100 random values between 0 and 2
y = 4 + 3 * X + np.random.randn(50, 1)  # Generate y with a random number

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions
x_new = np.array([[0],[14],[17],[30],[100]])  # New data points to make predictions on
y_hat = model.predict(X_new)

# %%
# Plot the original data and the regression line
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X_new, y_hat, color='red', linewidth=2, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.legend(['Original Data', 'Regression Line', 'Additional Label'])
plt.show()
